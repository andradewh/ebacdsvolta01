# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) RESULTADOS MULTIPLICADOS POR 100 PARA FACILITAR O ENTENDIMENTO DA RESPOSTA
p_mat = (df_mat /24)*100
p_por = (df_por /18)*100
p_geo = (df_geo /8)*100
p_ing = (df_ing /8)*100
p_his = (df_his /8)*100
p_fis = (df_fis /12)*100
p_qui = (df_qui /12)*100
p_qui
# Out:
#     Qt_acertos
# 0    25.000000
# 1    66.666667
# 2    33.333333
# 3    66.666667
# 4    25.000000
# ..         ...
# 95   25.000000
# 96   25.000000
# 97   41.666667
# 98   91.666667
# 99   16.666667
#
# [100 rows x 1 columns]

# %%
# 2) Seu código aqui
tot = (df_mat+df_por+df_geo+df_ing+df_his+df_fis+df_qui)
tot.head()
# Out:
#    Qt_acertos
# 0          35
# 1          48
# 2          50
# 3          32
# 4          30

# %%
# 3) Seu código aqui
p_geral = (tot/90)*100
p_geral
# Out:
#     Qt_acertos
# 0    38.888889
# 1    53.333333
# 2    55.555556
# 3    35.555556
# 4    33.333333
# ..         ...
# 95   37.777778
# 96   30.000000
# 97   44.444444
# 98   44.444444
# 99   46.666667
#
# [100 rows x 1 columns]

# %%
# 4) Seu código aqui
p_geral[p_geral['Qt_acertos'] > 45].count()
# Out:
# Qt_acertos    47
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
tot_zerados = tot[(df_mat['Qt_acertos'] == 0)|
                  (df_fis['Qt_acertos'] == 0)|
                  (df_qui['Qt_acertos'] == 0)]
tot_zerados

#print(df_mat[df_mat['Qt_acertos'] == 0])
#print(df_fis[df_fis['Qt_acertos'] == 0])
#print(df_qui[df_qui['Qt_acertos'] == 0])
# Out:
#     Qt_acertos
# 3           32
# 6           29
# 10          31
# 12          42
# 14          31
# 20          53
# 25          27
# 26          40
# 27          50
# 33          39
# 35          48
# 49          19
# 56          39
# 65          24
# 66          31
# 72          50
# 73          37
# 74          39
# 84          26
# 89          63
# 92          40
# 94          25
# 98          40

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-a719bbf0-d2ba-4bd8-a3d2-bd6f8cd0fe7c.c000.csv'

# %%
# ADICIONADO O DTYPE POR QUE ESTAVA DANDO ERRO DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
df = pd.read_csv(arquivo, sep=';', dtype='unicode') 
df.head()
# Out:
#                                  document_id  \
# 0  9c29303d-6aeb-47bd-bab9-2b0591789117-i0b0
# 1  de3d71a2-0e9c-428e-95e2-602fff1b911b-i0b0
# 2  814dc61e-b191-4b7d-ab53-a812a03f488e-i0b0
# 3  de60a6db-7777-44b2-92a2-f57c02dde17f-i0b0
# 4  34354f8c-3c50-4e13-a1c3-0408f6c6e805-i0b0
#
#                                          paciente_id paciente_idade  \
# 0  0bc4160e25e57eb324bc00a986e0bbec66a6e257627510...             20
# 1  fbde1256104decd0eb4f3aa7f8bffd6143bdd3b91fc415...             51
# 2  5b6620fa49070b23a5d1777591c1f7b20880e55b5009c6...             82
# 3  8acee3c68d4ea1707fda30a00a1ced3844bf0ae25ff840...             59
# 4  a68dfddc7be2fab179f19343eec8b7e8b27df20a5a4180...             19
#
#   paciente_dataNascimento paciente_enumSexoBiologico paciente_racaCor_codigo  \
# 0              2001-07-12                          M                      03
# 1              1969-09-12                          F                      03
# ...

# %%
# 1)
df.shape[0]
# Out:
# 547708

# %%
df.dtypes # verificando os tipos de dados, creio que por causa do dtype='unicode' ficaram todos como object
# Out:
# document_id                                 object
# paciente_id                                 object
# paciente_idade                              object
# paciente_dataNascimento                     object
# paciente_enumSexoBiologico                  object
# paciente_racaCor_codigo                     object
# paciente_racaCor_valor                      object
# paciente_endereco_coIbgeMunicipio           object
# paciente_endereco_coPais                    object
# paciente_endereco_nmMunicipio               object
# paciente_endereco_nmPais                    object
# paciente_endereco_uf                        object
# paciente_endereco_cep                       object
# paciente_nacionalidade_enumNacionalidade    object
# estabelecimento_valor                       object
# estabelecimento_razaoSocial                 object
# estalecimento_noFantasia                    object
# estabelecimento_municipio_codigo            object
# ...

# %%
# 2) 
df['paciente_id'].nunique()
# Out:
# 414950

# %%
# 3) 
df[df['vacina_descricao_dose'] == '1ª Dose'].paciente_id.nunique()
# Out:
# 227453

# %%
# OUTRA SOLUCAO
dose = df['vacina_descricao_dose'].unique()[0]
df['paciente_id'].loc[df['vacina_descricao_dose']==dose].nunique()
# Out:
# 227453

# %%
# NÃO ESTAVA CONSEGUINDO TRABALHAR COM O CAMPO IDADE POR QUE ESTAVA COMO STRING, COM ISSO TRANSFORMEI PARA NUMERICOS
func = (lambda valor: float(valor)) 
df['paciente_idade'] = df['paciente_idade'].apply(func)

# %%
# 4) 
df[df['paciente_idade']<18].paciente_id.nunique()
# Out:
# 77130

# %%
# OUTRA SOLUCAO
df_menor_idade = df[df["paciente_idade"]<18]
df_menor_idade['paciente_id'].nunique()
# Out:
# 77130

# %%
df[df["paciente_idade"]<18]
# Out:
#                                       document_id  \
# 7       df041b31-ac33-4248-b1b6-ec8ff3e69391-i0b0
# 12      2f29a59f-0a46-4554-a7b7-e9301915a013-i0b0
# 14      f3f586be-7391-4b80-b442-a3c3b4d5dc95-i0b0
# 17      df413930-7670-419f-ac13-33f344511b73-i0b0
# 19      df8ca8ec-1af0-46e8-87de-9af0a02168e4-i0b0
# ...                                           ...
# 547680  a2f1ef1e-fcb9-479f-b31f-31105fb83167-i0b0
# 547689  a48c8137-a9c9-4f9f-b983-099313b319e6-i0b0
# 547695  a580f1ae-4d46-4a57-812b-1a6e3ff1cdfe-i0b0
# 547702  a6964698-0414-4027-8931-528eb03458e3-i0b0
# 547704  a6d9902f-4cb2-43c3-ba74-882b6444a739-i0b0
#
#                                               paciente_id  paciente_idade  \
# 7       7e1a23d34247b5d633a35dd66e01073a644531481f7ba8...            13.0
# 12      02f8fbfda5ffb1edbbc08c2e95869b0cb8024554a06c2a...            15.0
# 14      1067758448cf94a365f03b01f9d073d03cc4ed8a0ae308...            16.0
# ...

# %%
# 5)
df['estabelecimento_razaoSocial'].nunique()
# Out:
# 49

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) 
df_menor = df[df["paciente_idade"]<18].copy()
df_menor.head()
# Out:
#                                   document_id  \
# 7   df041b31-ac33-4248-b1b6-ec8ff3e69391-i0b0
# 12  2f29a59f-0a46-4554-a7b7-e9301915a013-i0b0
# 14  f3f586be-7391-4b80-b442-a3c3b4d5dc95-i0b0
# 17  df413930-7670-419f-ac13-33f344511b73-i0b0
# 19  df8ca8ec-1af0-46e8-87de-9af0a02168e4-i0b0
#
#                                           paciente_id  paciente_idade  \
# 7   7e1a23d34247b5d633a35dd66e01073a644531481f7ba8...            13.0
# 12  02f8fbfda5ffb1edbbc08c2e95869b0cb8024554a06c2a...            15.0
# 14  1067758448cf94a365f03b01f9d073d03cc4ed8a0ae308...            16.0
# 17  eb9d3bd93a92bfc9a7b218d1e68158630e47dd03d1cfbc...            10.0
# 19  d8ec1d7ae60cde49c1ea3fa7cb14a79ca673b182395df4...            10.0
#
#    paciente_dataNascimento paciente_enumSexoBiologico paciente_racaCor_codigo  \
# 7               2008-01-13                          M                      03
# 12              2006-01-14                          M                      01
# ...

# %%
# 2) 
df_menor.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3)
df_menor['vacina_categoria_nome'].value_counts()
# Out:
# Faixa Etária                                      51490
# Outros                                             6115
# Povos Indígenas                                    2196
# Povos e Comunidades Tradicionais                    556
# Trabalhadores de Saúde                              395
# População Privada de Liberdade                       68
# Comorbidades                                         49
# Gestantes                                            30
# Pessoas com Deficiência                               3
# Pessoas de 60 anos ou mais institucionalizadas        1
# Puérperas                                             1
# Trabalhadores da Educação                             1
# Name: vacina_categoria_nome, dtype: int64

# %%
# 4)
columns_list = ['estabelecimento_valor',
       'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']

# %%
# 5)
df_menor_list = df_menor.loc[:,columns_list]
df_menor_list
# Out:
#        estabelecimento_valor                  estabelecimento_razaoSocial  \
# 7                    6159087      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 12                   6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 14                   2001349            PREFEITURA MUNICIPAL DE BRASILEIA
# 17                   6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 19                   2001772  PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS
# ...                      ...                                          ...
# 547680               6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 547689               3007367       PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 547695               6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 547702               3810771             PREFEITURA MUNICIPAL DE TARAUACA
# 547704               6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
#
#                                  estalecimento_noFantasia  \
# ...

# %%
# 6)
df_menor_list.drop_duplicates(inplace = True)
df_menor_list
# Out:
#        estabelecimento_valor                  estabelecimento_razaoSocial  \
# 7                    6159087      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 12                   6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 14                   2001349            PREFEITURA MUNICIPAL DE BRASILEIA
# 19                   2001772  PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS
# 28                   2000660     PREFEITURA MUNICIPAL DE SENADOR GUIOMARD
# ...                      ...                                          ...
# 170920               3042553            PREFEITURA MUNICIPAL DE BRASILEIA
# 213651               7123043               PREFEITURA MUNICIPAL DE JORDAO
# 228965               2000881       PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 236169               2000296                SECRETARIA DE ESTADO DE SAUDE
# 367828               7058322            PREFEITURA MUNICIPAL DE BRASILEIA
#
#                                  estalecimento_noFantasia  \
# ...

# %%
df_menor_list.shape
# Out:
# (113, 6)
